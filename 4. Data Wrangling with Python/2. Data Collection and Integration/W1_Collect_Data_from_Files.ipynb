# %% [markdown]
# <a href="https://colab.research.google.com/github/milanfx/Expressway-to-DTSA/blob/main/4.%20Data%20Wrangling%20with%20Python/2.%20Data%20Collection%20and%20Integration/W1_Collect_Data_from_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table width="850">
# <td bgcolor="#ba2f2a"><font color="white" size="8"><b>
# W1 Collect Data from Files
# </b></font></td></table>

# %% [markdown]
# <table width="850">
# <td bgcolor="#d5695d"><font color="white" size="6"><b>
# 1. Data Collection
# </b></font></td></table>

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.1 From CSV
# </b><br><br>
# Task:
# </font></td></table>

# %%
import pandas as pd

# %%
# header = 1, skiprows=0
df1 = pd.read_csv('https://raw.githubusercontent.com/milanfx/Dataset/main/DTSA/Data%20Wrangling/ds_salaries.csv', index_col=0)
df1.head(3)
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.2 From TXT
# </b><br><br>
# Task:
# </font></td></table>

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/milanfx/Dataset/main/DTSA/Data%20Wrangling/ds_salaries.txt', index_col=0)
df2.head(3)
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.3 From EXCEL
# </b><br><br>
# Task:
# </font></td></table>

# %%
df3 = pd.read_excel('/content/ds_salaries.xlsx', index_col=0)
df3.head(3)
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.4 From json
# </b><br><br>
# Task:
# </font></td></table>

# %%
df4 = pd.read_json('https://raw.githubusercontent.com/milanfx/Dataset/main/DTSA/Data%20Wrangling/ds_salaries.json')
df4.set_index("FIELD1", inplace=True, drop=True)
df4.head(3)
# Out:
#         work_year experience_level employment_type  \
# FIELD1
# 0            2020               MI              FT
# 1            2020               SE              FT
# 2            2020               SE              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# FIELD1
# 0                   Data Scientist   70000             EUR          79833
# 1       Machine Learning Scientist  260000             USD         260000
# 2                Big Data Engineer   85000             GBP         109024
#
#        employee_residence  remote_ratio company_location company_size
# FIELD1
# 0                      DE             0               DE            L
# 1                      JP             0               JP            S
# 2                      GB            50               GB            M

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.5 From XML
# </b><br><br>
# Task:
# </font></td></table>

# %%
df5 = pd.read_xml('https://raw.githubusercontent.com/milanfx/Dataset/main/DTSA/Data%20Wrangling/ds_salaries.xml')
df5.set_index("FIELD1", inplace=True, drop=True)
df5.head(3)
# Out:
#         work_year experience_level employment_type  \
# FIELD1
# 0            2020               MI              FT
# 1            2020               SE              FT
# 2            2020               SE              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# FIELD1
# 0                   Data Scientist   70000             EUR          79833
# 1       Machine Learning Scientist  260000             USD         260000
# 2                Big Data Engineer   85000             GBP         109024
#
#        employee_residence  remote_ratio company_location company_size
# FIELD1
# 0                      DE             0               DE            L
# 1                      JP             0               JP            S
# 2                      GB            50               GB            M

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB

# %% [markdown]
# <table width="850">
# <td bgcolor="#f8f2e4"><font color="black" size="4"><b>
# 1.5 From HTM
# </b><br><br>
# Task:
# </font></td></table>

# %%
df6 = pd.read_html('https://raw.githubusercontent.com/milanfx/Dataset/main/DTSA/Data%20Wrangling/ds_salaries.htm')[0]
df6.set_index("FIELD1", inplace=True, drop=True)
df6.head(3)
# Out:
#         work_year experience_level employment_type  \
# FIELD1
# 0            2020               MI              FT
# 1            2020               SE              FT
# 2            2020               SE              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# FIELD1
# 0                   Data Scientist   70000             EUR          79833
# 1       Machine Learning Scientist  260000             USD         260000
# 2                Big Data Engineer   85000             GBP         109024
#
#        employee_residence  remote_ratio company_location company_size
# FIELD1
# 0                      DE             0               DE            L
# 1                      JP             0               JP            S
# 2                      GB            50               GB            M

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 56.9+ KB
